# %% [markdown]
# Import Libraries and updates

# %%
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import json # library to handle JSON files
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML and XML documents
# !conda install -c conda-forge beautifulsoup4 --yes
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
print('Block1: Success')

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
print('Block2: Success')


# import k-means from clustering stage
from sklearn.cluster import KMeans
print('Block3: Success')

# !conda install -c conda-forge folium=0.5.0 --yes
#import folium # map rendering library
# !pip install folium

# !conda update -n base -c defaults conda 
print('Block4: Success')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Block1: Success
# Block2: Success
# Block3: Success
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: branca in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2->folium) (1.1.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.11.28)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     chardet-3.0.4              |        py37_1003         174 KB
#     ------------------------------------------------------------
#                                            Total:         174 KB
#
# The following packages will be REMOVED:
#
#   _libgcc_mutex-0.1-main
#   conda-env-2.6.0-1
#
# The following packages will be UPDATED:
#
#   chardet                                      3.0.4-py37_1 --> 3.0.4-py37_1003
#   libstdcxx-ng                             8.2.0-hdf63c60_1 --> 9.1.0-hdf63c60_0
#   openssl                                 1.1.1e-h7b6447c_0 --> 1.1.1f-h7b6447c_0
#   pysocks                                      1.6.8-py37_0 --> 1.7.1-py37_0
#   requests                                    2.21.0-py37_0 --> 2.23.0-py37_0
#   ruamel_yaml                        0.15.46-py37h14c3975_0 --> 0.15.87-py37h7b6447c_0
#   urllib3                                     1.24.1-py37_0 --> 1.25.8-py37_0
#
# The following packages will be DOWNGRADED:
#
#   pycosat                              0.6.3-py37h14c3975_0 --> 0.6.3-py37h7b6447c_0
#
#
#
# Downloading and Extracting Packages
# chardet-3.0.4        | 174 KB    | ###4                                  |   9% WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/recipe/recipe_log.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/recipe/meta.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/recipe/meta.yaml.template.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/recipe/conda_build_config.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/licenses/LICENSE.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/test/run_test.sh.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/test/run_test.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/about.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/files.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/index.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/paths.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/hash_input.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/git.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/has_prefix.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/repodata_record.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/bin/chardetect.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/LICENSE.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/RECORD.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/METADATA.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/WHEEL.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/top_level.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/INSTALLER.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/entry_points.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cli/__pycache__/__init__.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cli/__pycache__/chardetect.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cli/__init__.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cli/chardetect.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/utf8prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langbulgarianmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/latin1prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/big5prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langhebrewmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/mbcssm.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/universaldetector.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/version.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/euckrfreq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/sbcharsetprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/jisfreq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/mbcsgroupprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/__init__.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/compat.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langhungarianmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/eucjpprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/big5freq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/chardistribution.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/codingstatemachine.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/euckrprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/escsm.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/cp949prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/sbcsgroupprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/gb2312prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langgreekmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/mbcharsetprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/charsetprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/hebrewprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/euctwfreq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/sjisprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/jpcntx.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/euctwprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/charsetgroupprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/gb2312freq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langthaimodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/enums.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/escprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langcyrillicmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langturkishmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/big5prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/sbcharsetprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langhebrewmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/utf8prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/hebrewprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/escprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langthaimodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/jpcntx.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/gb2312freq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/escsm.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cp949prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__init__.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/mbcssm.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/sjisprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/euctwfreq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/euckrprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/charsetprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langbulgarianmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/euctwprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/version.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/universaldetector.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langcyrillicmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/euckrfreq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/enums.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langgreekmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/mbcsgroupprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/eucjpprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/chardistribution.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langhungarianmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/gb2312prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/compat.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/charsetgroupprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/latin1prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/jisfreq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langturkishmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/codingstatemachine.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/mbcharsetprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/big5freq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/sbcsgroupprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/recipe/recipe_log.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/recipe/meta.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/recipe/meta.yaml.template.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/recipe/conda_build_config.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/licenses/LICENSE.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/test/run_test.sh.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/test/run_test.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/about.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/files.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/index.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/paths.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/hash_input.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/git.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/has_prefix.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/info/repodata_record.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/bin/chardetect.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/LICENSE.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/RECORD.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/METADATA.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/WHEEL.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/top_level.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/INSTALLER.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet-3.0.4.dist-info/entry_points.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cli/__pycache__/__init__.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cli/__pycache__/chardetect.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cli/__init__.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cli/chardetect.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/utf8prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langbulgarianmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/latin1prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/big5prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langhebrewmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/mbcssm.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/universaldetector.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/version.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/euckrfreq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/sbcharsetprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/jisfreq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/mbcsgroupprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/__init__.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/compat.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langhungarianmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/eucjpprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/big5freq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/chardistribution.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/codingstatemachine.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/euckrprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/escsm.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/cp949prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/sbcsgroupprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/gb2312prober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langgreekmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/mbcharsetprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/charsetprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/hebrewprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/euctwfreq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/sjisprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/jpcntx.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/euctwprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/charsetgroupprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/gb2312freq.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langthaimodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/enums.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/escprober.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langcyrillicmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__pycache__/langturkishmodel.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/big5prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/sbcharsetprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langhebrewmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/utf8prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/hebrewprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/escprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langthaimodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/jpcntx.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/gb2312freq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/escsm.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/cp949prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/__init__.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/mbcssm.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/sjisprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/euctwfreq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/euckrprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/charsetprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langbulgarianmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/euctwprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/version.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/universaldetector.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langcyrillicmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/euckrfreq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/enums.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langgreekmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/mbcsgroupprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/eucjpprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/chardistribution.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langhungarianmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/gb2312prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/compat.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/charsetgroupprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/latin1prober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/jisfreq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/langturkishmodel.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/codingstatemachine.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/mbcharsetprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/big5freq.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/chardet-3.0.4-py37_1003/lib/python3.7/site-packages/chardet/sbcsgroupprober.py.  Please remove this file manually (you may need to reboot to free file handles)
# chardet-3.0.4        | 174 KB    | ##################################### | 100%
#
# InvalidArchiveError('Error with archive /opt/conda/pkgs/chardet-3.0.4-py37_10038inc26ux/info-chardet-3.0.4-py37_1003.tar.zst.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# Block4: Success

# %% [markdown]
# Read Wiki Table

# %%
# GET request
data = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

#url = ('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
#url = ('https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=890001695')
#results = requests.get(url).json
#results

# %%
soup = BeautifulSoup(data, 'html.parser')

# %% [markdown]
# Create Lists

# %%
PostalCodeList1 = []
BoroughList1 = []
NeighborhoodList1 = []

# %% [markdown]
# Read Table

# %%
soup.find('table').find_all('tr')

# find all the rows of the table
soup.find('table').find_all('tr')

# for each row of the table, find all the table data
for row in soup.find('table').find_all('tr'):
    cells = row.find_all('td')

# %%
for row in soup.find('table').find_all('tr'):
    cells = row.find_all('td')
    if(len(cells) > 0):
        PostalCodeList1.append(cells[0].text.rstrip('\n'))
        BoroughList1.append(cells[1].text.rstrip('\n'))
        NeighborhoodList1.append(cells[2].text.rstrip('\n'))

# %% [markdown]
# Create Dataframe

# %%
toronto_df1 = pd.DataFrame({"PostalCode": PostalCodeList1,
                           "Borough": BoroughList1,
                           "Neighborhood": NeighborhoodList1})

toronto_df1.head()
# Out:
#   PostalCode           Borough                Neighborhood
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York                   Parkwoods
# 3        M4A        North York            Victoria Village
# 4        M5A  Downtown Toronto  Regent Park / Harbourfront

# %% [markdown]
# Ignore cells with a borough that is Not assigned

# %%
toronto_df_drop1 = toronto_df1[toronto_df1.Borough != "Not assigned"].reset_index(drop=True)
toronto_df_drop1.head()
# Out:
#   PostalCode           Borough                                  Neighborhood
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 3        M6A        North York             Lawrence Manor / Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %% [markdown]
# Combine Neigborhoods

# %%
# group neighborhoods in the same borough
toronto_df_grouped = toronto_df_drop1.groupby(["PostalCode", "Borough"], as_index=False).agg(lambda x: ", ".join(x))
toronto_df_grouped.head()
# Out:
#   PostalCode      Borough                              Neighborhood
# 0        M1B  Scarborough                           Malvern / Rouge
# 1        M1C  Scarborough  Rouge Hill / Port Union / Highland Creek
# 2        M1E  Scarborough       Guildwood / Morningside / West Hill
# 3        M1G  Scarborough                                    Woburn
# 4        M1H  Scarborough                                 Cedarbrae

# %% [markdown]
# Assign Null Neighborhood Borough Values

# %%
# for Neighborhood="Not assigned", make the value the same as Borough
for index, row in toronto_df_grouped.iterrows():
    if row["Neighborhood"] == "Not assigned":
        row["Neighborhood"] = row["Borough"]
        
toronto_df_grouped.head()
# Out:
#   PostalCode      Borough                              Neighborhood
# 0        M1B  Scarborough                           Malvern / Rouge
# 1        M1C  Scarborough  Rouge Hill / Port Union / Highland Creek
# 2        M1E  Scarborough       Guildwood / Morningside / West Hill
# 3        M1G  Scarborough                                    Woburn
# 4        M1H  Scarborough                                 Cedarbrae

# %% [markdown]
# Testing

# %% [markdown]
# Print Shape

# %%
# print the number of rows of the cleaned dataframe
toronto_df_grouped.shape
# Out:
# (103, 3)
